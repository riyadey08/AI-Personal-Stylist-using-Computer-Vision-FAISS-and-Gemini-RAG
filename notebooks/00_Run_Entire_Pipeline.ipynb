# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run "/content/drive/MyDrive/AI_Personal_Stylist/notebooks/01_Pose_Detection.ipynb"
# Out:
# WARNING: Skipping mediapipe as it is not installed.
# Found existing installation: protobuf 5.29.6
# Uninstalling protobuf-5.29.6:
#   Successfully uninstalled protobuf-5.29.6
# Found existing installation: tensorflow 2.20.0
# Uninstalling tensorflow-2.20.0:
#   Successfully uninstalled tensorflow-2.20.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 56.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 28.3 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydf-tf 2.20.0 requires tensorflow==2.20.0, which is not installed.
# grain 0.2.18 requires protobuf>=5.28.3, but you have protobuf 4.25.3 which is incompatible.
# google-cloud-datastore 2.25.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 4.25.3 which is incompatible.
# ...

# %%
# %run "/content/drive/MyDrive/AI_Personal_Stylist/notebooks/02_Feature_Engineering.ipynb"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/AI_Personal_Stylist/datasets/landmarks.csv
# (3345, 133)
# 100%|██████████| 3345/3345 [00:02<00:00, 1365.49it/s]
# (3345, 44)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3345 entries, 0 to 3344
# Data columns (total 46 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   image_name             3345 non-null   object
#  1   height                 3345 non-null   float64
#  2   shoulder_width         3345 non-null   float64
#  3   hip_width              3345 non-null   float64
#  4   torso_length           3345 non-null   float64
#  5   left_upper_arm         3345 non-null   float64
#  6   right_upper_arm        3345 non-null   float64
#  7   left_forearm           3345 non-null   float64
#  8   right_forearm          3345 non-null   float64
# ...

# %%
# %run "/content/drive/MyDrive/AI_Personal_Stylist/notebooks/03_Parse_DeepFashion2.ipynb"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# True
# Total files: 383925
# Annotation Files: 191961
# {
#   "segmentation": [
#     [
#       419,
#       415,
#       349,
#       413,
#       252,
#       416,
#       270,
#       528,
#       298,
#       644,
#       298,
#       772,
#       327,
#       774,
#       347,
#       639,
#       347,
#       485,
#       352,
#       649,
#       335,
#       825,
#       361,
#       827,
#       392,
#       660,
#       409,
#       536,
#       419,
#       415
#     ],
#     [
#       349,
#       413,
#       252,
#       416,
#       270,
#       528,
#       298,
#       644,
#       298,
#       772,
#       327,
#       774,
#       347,
#       639,
#       347,
#       485,
#       349,
#       413
#     ],
#     [
#       419,
#       415,
#       349,
#       413,
#       347,
#       485,
#       352,
#       649,
#       335,
# ...

# %%
# %run "/content/drive/MyDrive/AI_Personal_Stylist/notebooks/04_Knowledge_Base.ipynb"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (5820, 54)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5820 entries, 0 to 5819
# Data columns (total 54 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   image_name             5820 non-null   object
#  1   height                 5820 non-null   float64
#  2   shoulder_width         5820 non-null   float64
#  3   hip_width              5820 non-null   float64
#  4   torso_length           5820 non-null   float64
#  5   left_upper_arm         5820 non-null   float64
#  6   right_upper_arm        5820 non-null   float64
#  7   left_forearm           5820 non-null   float64
#  8   right_forearm          5820 non-null   float64
#  9   left_arm               5820 non-null   float64
#  10  right_arm              5820 non-null   float64
# ...

# %%
# %run "/content/drive/MyDrive/AI_Personal_Stylist/notebooks/05_AIStylist_RAG.ipynb"
# Out:
# Found existing installation: protobuf 4.25.3
# Uninstalling protobuf-4.25.3:
#   Successfully uninstalled protobuf-4.25.3
# WARNING: Skipping tensorflow as it is not installed.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.9/173.9 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 4.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydf-tf 2.20.0 requires tensorflow==2.20.0, which is not installed.
# grain 0.2.18 requires protobuf>=5.28.3, but you have protobuf 4.25.3 which is incompatible.
# google-cloud-datastore 2.25.0 requires protobuf<8.0.0,>=4.25.8, but you have protobuf 4.25.3 which is incompatible.
# ...

# %%
print("=" * 70)
print("👗 AI PERSONAL STYLIST")
print("=" * 70)

print("\n✅ Entire pipeline executed successfully!")
print("✔ Pose Detection")
print("✔ Feature Engineering")
print("✔ Annotation Parsing")
print("✔ Knowledge Base & Embeddings")
print("✔ FAISS Retrieval")
print("✔ Gemini Recommendation")

print("\n" + "=" * 70)
print("💡 FINAL PERSONALIZED FASHION RECOMMENDATION")
print("=" * 70)

print(response.text)
# Out:
# ...
# 👗 AI PERSONAL STYLIST
# ...
#
# ✅ Entire pipeline executed successfully!
# ✔ Pose Detection
# ✔ Feature Engineering
# ✔ Annotation Parsing
# ✔ Knowledge Base & Embeddings
# ✔ FAISS Retrieval
# ✔ Gemini Recommendation
#
# ...
# 💡 FINAL PERSONALIZED FASHION RECOMMENDATION
# ...
# Hello there! As your AI Fashion Stylist, I’ve analyzed your body measurements and fashion profile to craft a personalized style blueprint just for you.
#
# Even though the automated "body shape" classifier returned *unknown*, your precise physical measurements tell a very clear and beautiful story! Let’s break down your unique proportions and find the absolute best ways to make you shine.
#
# ---
#
# ### 1. Your Body Shape Analysis
# Based on your measurements, you have a stunning and athletic **Inverted Triangle** silhouette with a **Long Torso / Shorter Leg** proportion:
# ...
